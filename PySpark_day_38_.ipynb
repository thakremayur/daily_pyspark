# %%
# ps-17
# %pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.3)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %%
# import all necessary module
from pyspark.sql import *
from pyspark.sql.types import *
from pyspark.sql.functions import *

# %%
# create spark session
spark = SparkSession.builder.master('local').appName('pyspark-day-38').getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://fcfb01110122:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-day-38</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# 𝐘𝐨𝐮𝐫 𝐦𝐢𝐬𝐬𝐢𝐨𝐧, 𝐬𝐡𝐨𝐮𝐥𝐝 𝐲𝐨𝐮 𝐜𝐡𝐨𝐨𝐬𝐞 𝐭𝐨 𝐚𝐜𝐜𝐞𝐩𝐭 𝐢𝐭, 𝐢𝐬 𝐭𝐨 𝐬𝐡𝐨𝐰𝐜𝐚𝐬𝐞 𝐲𝐨𝐮𝐫 𝐏𝐘𝐒𝐏𝐀𝐑𝐊 𝐩𝐫𝐨𝐰𝐞𝐬𝐬 𝐰𝐢𝐭𝐡 𝐭𝐡𝐞 𝐟𝐨𝐥𝐥𝐨𝐰𝐢𝐧𝐠 𝐭𝐚𝐬𝐤𝐬:
#
# 1️⃣ Write a pyspark code for combine FirstName and LastName and display it as "Name" (also include white space between first name & last name)
# 2️⃣ Select employee detail whose name is "Vikas"
# 3️⃣ Get all employee detail from EmployeeDetail table whose "FirstName" start with letter 'a'.
#
# ======================================
# 𝐒𝐜𝐡𝐞𝐦𝐚 𝐀𝐧𝐝 𝐃𝐚𝐭𝐚:
# ======================================
# # Input Data:
# data = [
#  [1, "Vikas", "Ahlawat", 600000.0, "2013-02-15 11:16:28.290", "IT", "Male"],
#  [2, "nikita", "Jain", 530000.0, "2014-01-09 17:31:07.793", "HR", "Female"],
#  [3, "Ashish", "Kumar", 1000000.0, "2014-01-09 10:05:07.793", "IT", "Male"],
#  [4, "Nikhil", "Sharma", 480000.0, "2014-01-09 09:00:07.793", "HR", "Male"],
#  [5, "anish", "kadian", 500000.0, "2014-01-09 09:31:07.793", "Payroll", "Male"],
# ]
#
# schema = StructType([
#  StructField("EmployeeID", IntegerType(), True),
#  StructField("First_Name", StringType(), True),
#  StructField("Last_Name", StringType(), True),
#  StructField("Salary", DoubleType(), True),
#  StructField("Joining_Date", StringType(), True),
#  StructField("Department", StringType(), True),
#  StructField("Gender", StringType(), True)
# ])

# %%
data = [
 [1, "Vikas", "Ahlawat", 600000.0, "2013-02-15 11:16:28.290", "IT", "Male"],
 [2, "nikita", "Jain", 530000.0, "2014-01-09 17:31:07.793", "HR", "Female"],
 [3, "Ashish", "Kumar", 1000000.0, "2014-01-09 10:05:07.793", "IT", "Male"],
 [4, "Nikhil", "Sharma", 480000.0, "2014-01-09 09:00:07.793", "HR", "Male"],
 [5, "anish", "kadian", 500000.0, "2014-01-09 09:31:07.793", "Payroll", "Male"],
]

schema = StructType([
 StructField("EmployeeID", IntegerType(), True),
 StructField("First_Name", StringType(), True),
 StructField("Last_Name", StringType(), True),
 StructField("Salary", DoubleType(), True),
 StructField("Joining_Date", StringType(), True),
 StructField("Department", StringType(), True),
 StructField("Gender", StringType(), True)
])

# %%
df = spark.createDataFrame(data = data, schema = schema)
df.show()
# Out:
# +----------+----------+---------+---------+--------------------+----------+------+
# |EmployeeID|First_Name|Last_Name|   Salary|        Joining_Date|Department|Gender|
# +----------+----------+---------+---------+--------------------+----------+------+
# |         1|     Vikas|  Ahlawat| 600000.0|2013-02-15 11:16:...|        IT|  Male|
# |         2|    nikita|     Jain| 530000.0|2014-01-09 17:31:...|        HR|Female|
# |         3|    Ashish|    Kumar|1000000.0|2014-01-09 10:05:...|        IT|  Male|
# |         4|    Nikhil|   Sharma| 480000.0|2014-01-09 09:00:...|        HR|  Male|
# |         5|     anish|   kadian| 500000.0|2014-01-09 09:31:...|   Payroll|  Male|
# +----------+----------+---------+---------+--------------------+----------+------+

# %%
df.select(concat_ws(' ','First_Name','Last_Name').alias("Name")).show()
# Out:
# +-------------+
# |         Name|
# +-------------+
# |Vikas Ahlawat|
# |  nikita Jain|
# | Ashish Kumar|
# |Nikhil Sharma|
# | anish kadian|
# +-------------+

# %%
df.filter(col('First_Name')=='Vikas').show()
# Out:
# +----------+----------+---------+--------+--------------------+----------+------+
# |EmployeeID|First_Name|Last_Name|  Salary|        Joining_Date|Department|Gender|
# +----------+----------+---------+--------+--------------------+----------+------+
# |         1|     Vikas|  Ahlawat|600000.0|2013-02-15 11:16:...|        IT|  Male|
# +----------+----------+---------+--------+--------------------+----------+------+

# %%
df.filter(lower(col('First_Name')).startswith('a')).show()
# Out:
# +----------+----------+---------+---------+--------------------+----------+------+
# |EmployeeID|First_Name|Last_Name|   Salary|        Joining_Date|Department|Gender|
# +----------+----------+---------+---------+--------------------+----------+------+
# |         3|    Ashish|    Kumar|1000000.0|2014-01-09 10:05:...|        IT|  Male|
# |         5|     anish|   kadian| 500000.0|2014-01-09 09:31:...|   Payroll|  Male|
# +----------+----------+---------+---------+--------------------+----------+------+
